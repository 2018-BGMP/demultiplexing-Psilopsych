# %% [markdown]
# zcat /projects/bgmp/shared/2017_sequencing/1294_S1_L008_R2_001.f
# astq.gz | sed -n '2~4p' | grep "N" | wc -l
#
# 3976613

# %% [markdown]
# zcat /projects/bgmp/shared/2017_sequencing/1294_S1_L008_R3_001.f
# astq.gz | sed -n '2~4p' | grep "N" | wc -l
#
# 3328051

# %% [markdown]
# **[Bash Script](/BashScript.sh)**
#
# **[Python Script](/posStatsN.py)**

# %% [markdown]
# A good quality score cutoff is 28 for the reads, and 35 for the index files.
# The quality score files cutoff is higher to ensure that the reads are properly indexed.

# %% [markdown]
# |File|Contents|
# |----|----|
# |R1|Read file one|
# |R2|Index file one|
# |R3|Index file two|
# |R4|Read file two|

# %%
from IPython.display import Image 
Image(filename = 'R1Means.png')

# %%
from IPython.display import Image 
Image(filename = 'R2Means.png')

# %%
from IPython.display import Image 
Image(filename = 'R3Means.png')

# %%
from IPython.display import Image 
Image(filename = 'R4Means.png')
